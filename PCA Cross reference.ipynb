# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing
import chart_studio.plotly as py
import plotly.graph_objects as go
from plotly.graph_objs import *
from plotly.offline import iplot

# %% [markdown]
# # Load data

# %%
df = pd.read_csv("historical_stock_prices.csv")
df_stock_industry = pd.read_csv("historical_stocks.csv")

# %%
#df = df_stocks[['ticker','close','date']][0:1000000].copy()

# %%
df.head()
# Out:
#   ticker   open  close  adj_close    low   high   volume        date
# 0    AHH  11.50  11.58   8.493155  11.25  11.68  4633900  2013-05-08
# 1    AHH  11.66  11.55   8.471151  11.50  11.66   275800  2013-05-09
# 2    AHH  11.55  11.60   8.507822  11.50  11.60   277100  2013-05-10
# 3    AHH  11.63  11.65   8.544494  11.55  11.65   147400  2013-05-13
# 4    AHH  11.60  11.53   8.456484  11.50  11.60   184100  2013-05-14

# %%
df_stock_industry.head()
# Out:
#   ticker exchange                                    name             sector  \
# 0    PIH   NASDAQ  1347 PROPERTY INSURANCE HOLDINGS, INC.            FINANCE
# 1  PIHPP   NASDAQ  1347 PROPERTY INSURANCE HOLDINGS, INC.            FINANCE
# 2   TURN   NASDAQ                180 DEGREE CAPITAL CORP.            FINANCE
# 3   FLWS   NASDAQ                 1-800 FLOWERS.COM, INC.  CONSUMER SERVICES
# 4   FCCY   NASDAQ           1ST CONSTITUTION BANCORP (NJ)            FINANCE
#
#                      industry
# 0  PROPERTY-CASUALTY INSURERS
# 1  PROPERTY-CASUALTY INSURERS
# 2  FINANCE/INVESTORS SERVICES
# 3      OTHER SPECIALTY STORES
# 4        SAVINGS INSTITUTIONS

# %% [markdown]
# # Add tech stocks to dataframe

# %%
print(df_stock_industry.sector.unique())
techTickers = df_stock_industry[df_stock_industry['sector'] == 'TECHNOLOGY']['ticker']

#for fast lookup of tech stocks
tech_map = map(techTickers.values, np.zeros(len(techTickers)))

print()
print("lenth of tech ticker: {0}".format(len(techTickers)))
# Out:
# ['FINANCE' 'CONSUMER SERVICES' 'TECHNOLOGY' 'PUBLIC UTILITIES'
#  'CAPITAL GOODS' 'BASIC INDUSTRIES' 'HEALTH CARE' 'CONSUMER DURABLES' nan
#  'ENERGY' 'MISCELLANEOUS' 'SECTOR' 'TRANSPORTATION'
#  'CONSUMER NON-DURABLES']
#
# lenth of tech ticker: 607

# %%
df[df['ticker'] == 'VNET'].reset_index(drop=True)
# Out:
#      ticker       open      close  adj_close    low       high    volume  \
# 0      VNET  20.260000  18.799999  18.799999  18.34  22.330000  18178500
# 1      VNET  19.400000  17.750000  17.750000  17.32  19.500000   2323400
# 2      VNET  17.700001  17.559999  17.559999  17.40  18.709999   1800000
# 3      VNET  17.840000  16.250000  16.250000  15.80  17.840000   1976500
# 4      VNET  16.110001  16.030001  16.030001  15.70  16.780001   1900000
# ...     ...        ...        ...        ...    ...        ...       ...
# 1844   VNET   9.090000   9.240000   9.240000   8.95   9.730000    653500
# 1845   VNET   9.300000  10.510000  10.510000   9.30  10.620000    808700
# 1846   VNET  10.450000  10.490000  10.490000  10.37  10.560000    533500
# 1847   VNET  10.520000  10.430000  10.430000  10.21  10.560000    369600
# 1848   VNET  10.500000  10.950000  10.950000  10.49  10.960000    393300
#
#             date
# 0     2011-04-21
# 1     2011-04-25
# 2     2011-04-26
# 3     2011-04-27
# 4     2011-04-28
# ...          ...
# 1844  2018-08-20
# 1845  2018-08-21
# 1846  2018-08-22
# 1847  2018-08-23
# 1848  2018-08-24
#
# [1849 rows x 8 columns]

# %%
df_tech_stocks = pd.DataFrame()
for t in techTickers:
    df_tech_stocks = df_tech_stocks.append(df[df['ticker'] == t])
    print(t)
# Out:
# VNET
# TWOU
# JOBS
# ACIA
# ACIW
# ACMR
# ATVI
# ACXM
# IOTS
# ADBE
# AMD
# AGYS
# AGMH
# AIRG
# AMCN
# ALRM
# ALLT
# MDRX
# AOSL
# GOOG
# GOOGL
# AABA
# ALTR
# AMBA
# DOX
# AMRH
# AMRHW
# AMSWA
# AMKR
# ASYS
# ADI
# ANSS
# APPF
# APPN
# AAPL
# AMAT
# AAOI
# APTI
# ARRS
# ASML
# AZPN
# ALOT
# ASUR
# TEAM
# ATOM
# ATTU
# ADSK
# ADP
# AUTO
# AVNW
# AVID
# AWRE
# ACLS
# AXTI
# BOSC
# BIDU
# BAND
# BBSI
# BNFT
# BILI
# BKYI
# BBOX
# BLKB
# BL
# BRQS
# EPAY
# BLIN
# BCOV
# AVGO
# BVSN
# BRKS
# CA
# CCMP
# CDNS
# CAMP
# CSIQ
# CBLK
# CARB
# CDLX
# CARG
# CASA
# CAVM
# CRNT
# CERN
# CEVA
# CYOU
# CHKP
# CNIT
# CCIH
# CNET
# IMOS
# CRUS
# CSCO
# CTXS
# CTSH
# CHUBA
# CHUBK
# COMM
# CVLT
# CPSI
# CTG
# CMTL
# CVON
# CVONW
# CSOD
# CPAH
# COUP
# CRAY
# CREE
# CRTO
# CCRN
# CSGS
# CSPI
# CVV
# CYBR
# CY
# CYRN
# DWCH
# DTRM
# DGII
# DMRC
# DGLY
# DIOD
# DLHC
# DOCU
# DBX
# DSPG
# EBIX
# ELON
# SATS
# EDGW
# EGAN
# EA
# EFII
# ELTK
# EMKR
# EIGI
# WATT
# ERII
# ENPH
# PLUS
# ERIC
# EVBG
# MRAM
# EVOL
# EXTR
# FFIV
# FB
# FNSR
# FEYE
# FSLR
# FISV
# FIVN
# FLEX
# FPAY
# FSCT
# FRSX
# FORM
# FORTY
# FTNT
# FSNN
# GDS
# GFN
# GFNCP
# GFNSL
# GIGM
# GILT
# GLUU
# GEC
# GSUM
# GRPN
# GVP
# GSIT
# HQCL
# HLIT
# HSTM
# HSII
# HIMX
# HDP
# HSON
# ICHR
# ICLK
# INVE
# INFO
# IMMR
# IMPV
# INOD
# ISSC
# INOV
# INPX
# INSE
# IDTI
# INTC
# LINK
# IMI
# INAP
# IIJI
# INTX
# IVAC
# INTU
# IPAS
# IPGP
# JCOM
# JASO
# JKHY
# JMU
# KELYA
# KELYB
# KTCC
# KFRC
# KE
# KONE
# KOPN
# KLIC
# KVHI
# LRCX
# LTRX
# LSCC
# LTRPA
# LTRPB
# LPTH
# LECO
# LPSN
# LOGI
# LOGM
# LFIN
# LORL
# MTSI
# MGIC
# MNGA
# MAMS
# MANH
# MNTX
# MRVL
# MTCH
# MTLS
# MATR
# MXIM
# MGRC
# MDCA
# MTBC
# MTBCP
# MDSO
# MLNX
# MCHP
# MU
# MSCC
# MSFT
# MSTR
# MIME
# MNDO
# MB
# MIND
# MINDP
# MITK
# MITL
# MOBL
# MOMO
# MDB
# MPWR
# TYPE
# MOSY
# MOXC
# MYSZ
# NNDM
# NH
# NATI
# NETE
# NTAP
# NLST
# NTCT
# NTWK
# NICE
# LASR
# NUAN
# NTNX
# NVEC
# NVDA
# NXPI
# TGH
# RUBI
# TRTN
# TBI
# TWLO
# TWTR
# TYL
# UIS
# UMC
# URI
# VEEV
# VMW
# WBT
# WIT
# WK
# WPP
# XRX
# YEXT
# YGE
# ZEN
# ZUO

# %%
df_tech_stocks
# Out:
#         ticker       open      close  adj_close        low       high  \
# 3114938   VNET  20.260000  18.799999  18.799999  18.340000  22.330000
# 3114942   VNET  19.400000  17.750000  17.750000  17.320000  19.500000
# 3114943   VNET  17.700001  17.559999  17.559999  17.400000  18.709999
# 3114944   VNET  17.840000  16.250000  16.250000  15.800000  17.840000
# 3114962   VNET  16.110001  16.030001  16.030001  15.700000  16.780001
# ...        ...        ...        ...        ...        ...        ...
# 2961572    ZUO  29.900000  28.299999  28.299999  28.055000  29.990000
# 2961582    ZUO  28.280001  28.799999  28.799999  28.231001  29.330000
# 2961594    ZUO  28.389999  29.719999  29.719999  28.337000  30.000000
# 2961603    ZUO  29.870001  30.170000  30.170000  29.170000  30.850000
# 2961615    ZUO  30.379999  33.380001  33.380001  30.322001  33.480000
#
#            volume        date
# 3114938  18178500  2011-04-21
# 3114942   2323400  2011-04-25
# 3114943   1800000  2011-04-26
# 3114944   1976500  2011-04-27
# 3114962   1900000  2011-04-28
# ...           ...         ...
# 2961572    971000  2018-08-20
# 2961582    979800  2018-08-21
# 2961594    761900  2018-08-22
# 2961603   1047100  2018-08-23
# 2961615   1808800  2018-08-24
#
# [2107718 rows x 8 columns]

# %%
listOfTechStocks = []

for t in df['ticker'].unique():
    if t in techTickers:
        listOfTechStocks.add(t)
    else:
        indexNames = df[df['ticker'] == t ].index
        df.drop(indexNames , inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-82-fdfff6b13f77> in <module>
#       6     else:
#       7         indexNames = df[df['ticker'] == t ].index
# ----> 8         df.drop(indexNames , inplace=True)
#
# Z:\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# Z:\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# Z:\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3945             else:
#    3946                 new_axis = axis.drop(labels, errors=errors)
# -> 3947             result = self.reindex(**{axis_name: new_axis})
#    3948
#    3949         # Case for non-unique axis
#
# Z:\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     219         @wraps(func)
#     220         def wrapper(*args, **kwargs):
# --> 221             return func(*args, **kwargs)
#     222
#     223         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# Z:\Anaconda3\lib\site-packages\pandas\core\frame.py in reindex(self, *args, **kwargs)
#    3959         kwargs.pop("axis", None)
#    3960         kwargs.pop("labels", None)
# -> 3961         return super().reindex(**kwargs)
#    3962
#    3963     def drop(
#
# Z:\Anaconda3\lib\site-packages\pandas\core\generic.py in reindex(self, *args, **kwargs)
#    4512         # perform the reindex on the axes
#    4513         return self._reindex_axes(
# -> 4514             axes, level, limit, tolerance, method, fill_value, copy
#    4515         ).__finalize__(self)
#    4516
#
# Z:\Anaconda3\lib\site-packages\pandas\core\frame.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    3847         if index is not None:
#    3848             frame = frame._reindex_index(
# -> 3849                 index, method, copy, level, fill_value, limit, tolerance
#    3850             )
#    3851
#
# Z:\Anaconda3\lib\site-packages\pandas\core\frame.py in _reindex_index(self, new_index, method, copy, level, fill_value, limit, tolerance)
#    3863     ):
#    3864         new_index, indexer = self.index.reindex(
# -> 3865             new_index, method=method, level=level, limit=limit, tolerance=tolerance
#    3866         )
#    3867         return self._reindex_with_indexers(
#
# Z:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in reindex(self, target, method, level, limit, tolerance)
#    3406                 if self.is_unique and not getattr(self, "is_overlapping", False):
#    3407                     indexer = self.get_indexer(
# -> 3408                         target, method=method, limit=limit, tolerance=tolerance
#    3409                     )
#    3410                 else:
#
# Z:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_indexer(self, target, method, limit, tolerance)
#    3002                 )
#    3003
# -> 3004             indexer = self._engine.get_indexer(target._ndarray_values)
#    3005
#    3006         return ensure_platform_int(indexer)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_indexer()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.lookup()
#
# Z:\Anaconda3\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     467
#     468
# --> 469 @set_module('numpy')
#     470 def asarray(a, dtype=None, order=None):
#     471     """Convert the input to an array.
#
# KeyboardInterrupt:

# %%
df

# %%
df_tech_stocks.to_csv('Tech_stock_prices.csv')
